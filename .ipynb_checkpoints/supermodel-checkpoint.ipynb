# %%
import psycopg2
from sqlalchemy import create_engine, Column, Integer, String, Float, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship, sessionmaker
import re
from __future__ import print_function

# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs
from sklearn import feature_extraction
import mpld3

from nltk.stem.snowball import SnowballStemmer

# %%
Base = declarative_base()

# %%
class Recipe(Base):
    __tablename__ = 'recipes'
    
    id = Column(Integer, primary_key=True)
    name = Column(String)
    url = Column(String, unique=True)
    calories = Column(Integer)
    fat = Column(Float)
    carbs = Column(Float)
    protein = Column(Float)
    cholesterol = Column(Float)
    sodium = Column(Float)
    servings = Column(Integer)
    #ingredients = 
    #__table_args__ = {'extend_existing': True}
    
    def __repr__(self):
        return "<Recipe(name='%s', url='%s')>" % (
            self.name, self.url)
    
class Ingredient(Base):
    __tablename__ = 'ingredients'
    id = Column(Integer, primary_key = True)
    ingredient = Column(String, nullable = False)
    recipe_id = Column(Integer, ForeignKey('recipes.id'))
    
    recipe = relationship(Recipe, back_populates = 'ingredients')
    #__table_args__ = {'extend_existing': True}
    def __repr__(self):
        return "<Ingredient(ingredient='%s')>" % self.ingredient

Recipe.ingredients = relationship("Ingredient", order_by=Ingredient.id, back_populates="recipe")

class Restaurant(Base):
    __tablename__ = 'restaurants'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    url = Column(String)
    zomatoID = Column(Integer, unique=True)
    costfortwo = Column(Float)
    featured_image = Column(String)
    photos = Column(String)
    menu_url = Column(String)
    price_range = Column(Integer)
    latitude = Column(Float)
    longitude = Column(Float)
    address = Column(String)
    
    def __repr__(self):
        return "<Restaurant(name='%s', url='%s')>" % (
            self.name, self.url)

class MenuItem(Base):
    __tablename__ = 'menuitems'
    id = Column(Integer, primary_key=True)
    menuitem = Column(String, nullable = False)
    description = Column(String)
    restaurant_id = Column(Integer, ForeignKey('restaurants.id'))
    price = Column(String)
    
    restaurant = relationship(Restaurant, back_populates = 'menuitems')
    __table_args__ = {'extend_existing': True}
    def __repr__(self):
        return "<MenuItem(item='%s', desc='%s')>" % (
            self.menuitem, self.description)
    
Restaurant.menuitems = relationship("MenuItem", order_by=MenuItem.id, back_populates="restaurant")

# %%
measurements = ("femtogram", "gigagram", "gram", "hectogram", "kilogram", \
                "long", "ton", "mcg", "megagram", "metric", "ton", "metric"\
                "tonne", "microgram", "milligram","nanogram", "ounce", \
                "lb", "oz", "each", "pound", "short", "Gram", "Ounce", "Pint", "Quart",\
                "Tablespoon", "Teaspoon", "Tablespoons", "Teaspoons", "Cups", "cup","Fluid Ounce", "fl oz", "Gallon", "Ounce", \
                "Pint", "Quart", "Tablespoon", "Teaspoon", "liter", "litre", "L", "ml", "fluid ounces", "can", "cans")

# %%
def find_measurement_words(i):
    ingredient_line = i
    for item in measurements:
        meas = str(" " + item.lower() + " ")
        a = re.search(meas, ingredient_line)
        if a > 0:
            unit = ingredient_line[a.start():a.end()].strip()
            quantity = ingredient_line[:a.start()].strip()
            ingredient = ingredient_line[a.end():].strip()
            break
        else:
            ilist = i.split(" ")
            quantity = ilist[0]
            unit = "each"
            ingredient = " ".join(ilist[1:])
    newitem = {"ingredient": ingredient,
    "unit": unit,
    "quantity":  quantity}
    try:
        fracsplit = ([float(k) for k in newitem["quantity"].split("/")])
        if len(fracsplit) >= 2:
            newitem["quantity"] = fracsplit[0] / fracsplit[1]
    except:
        None
    #print(newitem)
    return newitem

# %%
def clean_up_ingredient(ingredient_line):
    ingredient_line = re.sub("\[u\'", "", ingredient_line)
    ingredient_line = re.sub("\']", "", ingredient_line)
    return find_measurement_words(ingredient_line)

# %%
dbname = 'restaurants'
username = 'andylane'
engine = create_engine('postgres://%s@localhost/%s'%(username,dbname))
print(engine.url)
# Out:
# postgres://andylane@localhost/restaurants
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/sqlalchemy/dialects/__init__.py:34: SADeprecationWarning: The SQLAlchemy PostgreSQL dialect has been renamed from 'postgres' to 'postgresql'. The new URL format is postgresql[+driver]://<user>:<pass>@<host>/<dbname>
#   module = __import__('sqlalchemy.dialects.%s' % (dialect, )).dialects

# %%
con = None
con = psycopg2.connect(database = "restaurants", user = "andylane")
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ##Get recipe names into a vector

# %%
names = session.query(Recipe).all()

# %%
titles=[]
for item in names:
    titles.append(item.name)

# %% [markdown]
# ##Get ingredient lists into vector, order matching names

# %%
synopses = []
for item in names:
    synopses.append(" ".join([clean_up_ingredient(a.ingredient)["ingredient"] for a in item.ingredients]))

# %%
recipeids = []
for item in names:
    recipeids.append(item.id)

# %%
calories=[]
for item in names:
    calories.append(item.calories)

# %%
cholesterol=[]
for item in names:
    cholesterol.append(item.cholesterol)

# %% [markdown]
# http://brandonrose.org/clustering

# %%
stopwords = nltk.corpus.stopwords.words('english')
stemmer = SnowballStemmer("english")

# %% [markdown]
# ## Match menu items to a cluster

# %%
def tokenize_and_stem(title):
    stemmer = SnowballStemmer("english")
    stemmed_titles = []
    new_title=[]
    for word in nltk.word_tokenize(title):
        new_title.append(stemmer.stem(word))
    stemmed_titles.extend(new_title)
    return [i for i in stemmed_titles]

# %%
nltk.word_tokenize("braised short ribs")
# Out:
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/IPython/core/formatters.py:92: DeprecationWarning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
#   def _ipython_display_formatter_default(self):
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# /home/andylane/anaconda2/envs/insight/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# ['braised', 'short', 'ribs']

# %%
def cluster_recipes(titles, num_clusters = 380): 
    def tokenize_and_stem(title):
        stemmer = SnowballStemmer("english")
        stemmed_titles = []
        new_title=[]
        for word in nltk.word_tokenize(title):
            new_title.append(stemmer.stem(word))
        stemmed_titles.extend(new_title)
        return [i for i in stemmed_titles]

    def tokenize_only(title):
        tokenized_titles = []
        new_title=[]
        for word in nltk.word_tokenize(title):
            new_title.append(word)
        tokenized_titles.extend(new_title)
        return [i for i in tokenized_titles]

    #not super pythonic, no, not at all.
    #use extend so it's a big flat list of vocab
    totalvocab_stemmed = []
    totalvocab_tokenized = []
    for i in titles:
        totalvocab_stemmed.extend([j for j in tokenize_and_stem(i)])
        totalvocab_tokenized.extend([k for k in tokenize_only(i)])

    vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)

    from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

    #define vectorizer parameters
    tfidf_vectorizer = TfidfVectorizer(max_df=0.9, max_features=200000,
                                     min_df=0.01, stop_words='english',
                                     use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

    count_vectorizer = CountVectorizer(max_df=0.9, max_features=200000,
                                     min_df=0.01, stop_words='english', tokenizer=tokenize_and_stem, ngram_range=(1,3))


    tfidf_matrix = tfidf_vectorizer.fit_transform(titles) #fit the vectorizer to synopses

    print(tfidf_matrix.shape)

    terms = tfidf_vectorizer.get_feature_names()

    from sklearn.metrics.pairwise import cosine_similarity
    dist = 1 - cosine_similarity(tfidf_matrix)

    from sklearn.cluster import KMeans
    #num_clusters = 380
    km = KMeans(n_clusters=num_clusters)
    km.fit(tfidf_matrix)
    clusters = km.labels_.tolist()
    
    from sklearn.externals import joblib
    #uncomment the below to save your model 
    #since I've already run my model I am loading from the pickle
    #joblib.dump(km,  'doc_cluster.pkl')
    #km = joblib.load('doc_cluster.pkl')
    recipes = {'title': titles,
               'synopsis': synopses,
               'calories': calories,
               'cholesterol': cholesterol,
               'cluster': clusters,
               'recipeid': recipeids}
    frame = pd.DataFrame(recipes, index = [clusters] , columns = ['title', 'cluster', 'calories', 'cholesterol', 'recipeid'])
    frame['cluster'].value_counts()
    grouped = frame['cholesterol'].groupby(frame['cluster']) #groupby cluster for aggregation purposes
    grouped.mean() #average rank (1 to 100) per cluster
    return {"cluster_designations": frame, "vectorizer": tfidf_vectorizer, "model": km}

# %% [markdown]
# ## Assign description to a cluster

# %%
def cluster_ingredients(synopses, num_clusters = 100):
    '''
    Input: a list containing space-separated ingredients for a set of recipes.
    Output: a scikit-learn k-means model object 
    '''
    
    # here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed
    def tokenize_and_stem(text):
        stemmer = SnowballStemmer("english")
        # first tokenize by sentence, then by word to ensure that punctuation is caught as its own token
        tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
        filtered_tokens = []
        # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
        for token in tokens:
            if re.search('[a-zA-Z]', token):
                filtered_tokens.append(token)
        stems = [stemmer.stem(t) for t in filtered_tokens]
        return stems


    def tokenize_only(text):
        # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
        tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
        filtered_tokens = []
        # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
        for token in tokens:
            if re.search('[a-zA-Z]', token):
                filtered_tokens.append(token)
        return filtered_tokens

    #not super pythonic, no, not at all.
    #use extend so it's a big flat list of vocab
    totalvocab_stemmed = []
    totalvocab_tokenized = []
    for i in synopses:
        allwords_stemmed = tokenize_and_stem(i) #for each item in 'synopses', tokenize/stem
        totalvocab_stemmed.extend(allwords_stemmed) #extend the 'totalvocab_stemmed' list

        allwords_tokenized = tokenize_only(i)
        totalvocab_tokenized.extend(allwords_tokenized)

    vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)
    print('there are ' + str(vocab_frame.shape[0]) + ' items in vocab_frame')
    print(vocab_frame.head())

    from sklearn.feature_extraction.text import TfidfVectorizer

    #define vectorizer parameters
    tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                     min_df=0.2, stop_words='english',
                                     use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

    tfidf_matrix = tfidf_vectorizer.fit_transform(synopses) #fit the vectorizer to synopses

    print(tfidf_matrix.shape)
    terms = tfidf_vectorizer.get_feature_names()

    from sklearn.metrics.pairwise import cosine_similarity
    dist = 1 - cosine_similarity(tfidf_matrix)

    from sklearn.cluster import KMeans
    #num_clusters = 100
    km = KMeans(n_clusters=num_clusters)
    km.fit(tfidf_matrix)
    clusters = km.labels_.tolist()

    from sklearn.externals import joblib
    #uncomment the below to save your model 
    #since I've already run my model I am loading from the pickle
    #joblib.dump(km,  'doc_cluster.pkl')
    #km = joblib.load('doc_cluster.pkl')
    recipes = {'title': titles,
               'synopsis': synopses,
               'calories': calories,
               'cholesterol':cholesterol,
               'cluster': clusters,
               'recipeid': recipeids}
    frame = pd.DataFrame(recipes, index = [clusters] , columns = ['title', 'cluster', 'calories', 'cholesterol', 'recipeid'])
    frame['cluster'].value_counts()
    grouped = frame['cholesterol'].groupby(frame['cluster']) #groupby cluster for aggregation purposes
    grouped.mean() #average rank (1 to 100) per cluster
    return {"cluster_designations": frame, "vectorizer": tfidf_vectorizer, "model": km}

# %%
recipe_clusters = cluster_recipes(titles)
# Out:
# (3941, 96)

# %%
ingredient_clusters = cluster_ingredients(synopses)
# Out:
# there are 117798 items in vocab_frame
#                   words
# milk               milk
# white             white
# vinegar         vinegar
# all-purpos  all-purpose
# flour             flour
# (3941, 36)

# %%
X_new = recipe_clusters['vectorizer'].transform(["salad"])
prediction = recipe_clusters['model'].predict(X_new)

# %%
# Predicts the cluster that a list of ingredients is in.
prediction
# Out:
# array([23], dtype=int32)

# %%
a = recipe_clusters["cluster_designations"].ix[prediction[0]]

# %%
from collections import Counter
from operator import itemgetter

# %%
def classify_menu_item(menu_item, menu_item_description, recipe_clusters, ingredient_clusters):
    menu_item = " ".join(tokenize_and_stem(menu_item))
    vectorized_menu_item = recipe_clusters["vectorizer"].transform([menu_item]) #can later pass a list of menu_items
    recipe_cluster = recipe_clusters["model"].predict(vectorized_menu_item)
    #print(recipe_cluster)
    description = " ".join(tokenize_and_stem(menu_item_description))
    #look up ingredient clusters list; return found ingredient clusters matching recipes
    # assign menu item description to an ingredient cluster
    # ask if there's a match
    matching_recipes = recipe_clusters["cluster_designations"].ix[recipe_cluster]
    recipematchdict = {}
    for item in matching_recipes["recipeid"]:
        ingredient_cluster = ingredient_clusters['cluster_designations'].loc[ingredient_clusters['cluster_designations']['recipeid'] == item]["cluster"].iloc[0]
        recipe_name = session.query(Recipe).filter(Recipe.id == int(item)).all()[0].name
        recipematchdict[recipe_name] = ingredient_cluster
    # some horrible code to count and sort the matching ingredient clusters...
    top_recipe_cluster = sorted(list(Counter([item[1] for item in recipematchdict.iteritems()]).iteritems()), key=itemgetter(1), reverse=True)[0][0]
    # mean cholesterol in that matching recipe cluster
    predicted_cholesterol = np.mean(recipe_clusters["cluster_designations"].ix[top_recipe_cluster]["cholesterol"])
        
    return predicted_cholesterol

# %%
recipe_clusters["cluster_designations"].ix[]
# Out:
#                                              title  cluster  calories  \
# 2                                  Fluffy Pancakes        2       230
# 2                           Campfire Banana Splits        2       545
# 2                          Morning Glory Muffins I        2       194
# 2                                   Millet Muffins        2       176
# 2   Fluffy Pancakes with Wheat Germ and Applesauce        2       174
# 2                      Extra-Yummy Fluffy Pancakes        2       218
# 2           Healthier To Die For Blueberry Muffins        2       317
# 2                            Fluffy Vegan Pancakes        2       222
# 2                          Dark Guinness® Brownies        2       236
# 2                         Fluffy Canadian Pancakes        2       197
# 2                                  Tofu Parmigiana        2       357
# 2                       Blueberry Streusel Muffins        2       251
# 2                                 Cottage Meatloaf        2       325
# 2                          Fluffy Swedish Pancakes        2       481
# 2                             Banana Crumb Muffins        2       263
# 2                             Dill Pickle Meatloaf        2       300
# 2                           My Cinco de Mayo Chili        2       420
# 2                        Milk-Free Fluffy Pancakes        2       291
# 2                              Prize Winning Chili        2       242
# 2                      Gluten-Free Fluffy Pancakes        2       248
# 2                           Rempel Family Meatloaf        2       360
# 2               Leftover Halloween Candy Brownies!        2       222
# 2                Streusel Topped Blueberry Muffins        2       266
# 2                     To Die For Blueberry Muffins        2       383
# 2                                     Quinoa Chili        2       412
# 2                            Blueberry Oat Muffins        2       203
# 2             Jordan Marsh Style Blueberry Muffins        2       258
# 2                             Whole Wheat Pancakes        2       548
# 2                      Good Old Fashioned Pancakes        2       158
# 2                   Healthier Brown Sugar Meatloaf        2       265
# ..                                             ...      ...       ...
# 2                       Hearty Breakfast Specialty        2       441
# 2                        Italian-Style Swiss Chard        2        75
# 2                                Veggie Stroganoff        2       457
# 2                            Barbecued Korean Ribs        2       995
# 2                             Cheeseburger Muffins        2       174
# 2                                   Veggie Lasagna        2       529
# 2                     Gluten-Free Margherita Pizza        2       228
# 2                              Finger Licking Ribs        2       457
# 2                       Awesome Eggplant Rollatine        2       938
# 2                     Christmas Morning Life Saver        2       459
# 2                             Asian Vegetable Roll        2       373
# 2                        Weeknight Skillet Fajitas        2       518
# 2                    How to Make Turkey Manicotti         2       343
# 2                                      Veggie Loaf        2       302
# 2                                    Pizza Supreme        2       417
# 2                           Cheese-Garlic Biscuits        2       166
# 2                         Cinnamon Sugar Snap Peas        2        81
# 2         Cheddar Biscuits with OLD BAY® Seasoning        2       282
# 2                               Strawberry Pavlova        2       281
# 2                            Fish Fillets Italiano        2       230
# 2                        French Canadian Tourtiere        2       405
# 2                 New England Clam Chowder for Two        2       676
# 2                                       Flag Pizza        2       463
# 2                                  Tuna Fish Tacos        2       228
# 2              Salt-Crusted Lemon-Dill Cod Fillets        2       296
# 2                   Italian-Style Zucchini Lasagna        2       386
# 2   Savory Turkey Meatballs with Tangy Mustard Dip        2       120
# 2                                Chinese Spareribs        2       909
# 2                           Brown Sugar Shortbread        2        78
# 2                             Sausage-Cheese Balls        2       220
#
#     cholesterol  recipeid
# 2          65.0         1
# 2           0.0         4
# 2          10.0        11
# 2          12.0        18
# 2          78.0        26
# 2          35.0        28
# 2          39.0        31
# 2           0.0        44
# 2          40.0        56
# 2         159.0        58
# 2          24.0        71
# 2          57.0        75
# 2         110.0        76
# 2         260.0        79
# 2          38.0        88
# 2         124.0        91
# 2          96.0        95
# 2          62.0       112
# 2          44.0       118
# 2         132.0       123
# 2         143.0       125
# 2          24.0       127
# 2          57.0       138
# 2          39.0       148
# 2          45.0       152
# 2          16.0       160
# 2          32.0       162
# 2         163.0       165
# 2          38.0       171
# 2         106.0       176
# ..          ...       ...
# 2          15.0      3060
# 2           0.0      3071
# 2          58.0      3096
# 2         186.0      3200
# 2          48.0      3216
# 2          53.0      3231
# 2          86.0      3273
# 2         120.0      3320
# 2         285.0      3322
# 2         200.0      3360
# 2           0.0      3378
# 2          69.0      3397
# 2         139.0      3452
# 2          46.0      3487
# 2          33.0      3542
# 2          15.0      3563
# 2           0.0      3596
# 2          45.0      3662
# 2          65.0      3664
# 2          41.0      3690
# 2          55.0      3699
# 2          95.0      3718
# 2          55.0      3797
# 2          11.0      3851
# 2         104.0      3880
# 2          94.0      3922
# 2          55.0      3983
# 2         240.0      3998
# 2          13.0      4011
# 2          37.0      4033
#
# [171 rows x 5 columns]

# %%
ingredient_clusters['cluster_designations'].loc[ingredient_clusters['cluster_designations']['recipeid'] == 384]
# Out:
#               title  cluster  calories  cholesterol  recipeid
# 99  Thai Pork Satay       99       276         49.0       384

# %%
a= classify_menu_item("salad", "", recipe_clusters, ingredient_clusters)

# %%
a
# Out:
# 79.57142857142857

# %%
menu_items = session.query(MenuItem).filter(MenuItem.restaurant_id == 82).all()

# %%
[item.menuitem.encode("utf-8") for item in session.query(MenuItem).filter(MenuItem.restaurant_id == 9).all()]

# %%
ingredient_clusters
# Out:
# {'cluster_designations':                                               title  cluster  calories  \
#  83                                  Fluffy Pancakes       83       230
#  49                               Joan's Quick Chili       49       397
#  54                Ultimate Double Chocolate Cookies       54       148
#  34                           Campfire Banana Splits       34       545
#  9                 Pumpkin Chocolate Chip Cookies II        9       224
#  59                             Bake Sale Lemon Bars       59       107
#  9                             Apple Breakfast Bread        9       279
#  51                  Spinach Stuffed Chicken Breasts       51       449
#  66                      Fennel and Watercress Salad       66       178
#  83                       Almost No Fat Banana Bread       83       127
#  83                          Morning Glory Muffins I       83       194
#  36                       Sweet Russian Cabbage Soup       36       688
#  83                             My Mother's Pancakes       83       357
#  68             Chicken Breasts in Caper Cream Sauce       68       313
#  70                          Baked Ziti with Sausage       70       649
#  98                              Banana Banana Bread       98       229
#  36              Grilled Lamb with Brown Sugar Glaze       36       241
#  31                                   Millet Muffins       31       176
#  98           Thick and Chewy Chocolate Chip Cookies       98       160
#  47                    Delicious Ham and Potato Soup       47       195
#  13                            Pork and Cabbage Soup       13       438
#  54                    Irresistible Irish Soda Bread       54       192
#  98                            Glazed Pumpkin Donuts       98       262
#  78      Homemade Chicken Cacciatore, Sicilian-Style       78       875
#  60                                  Mary's Meatloaf       60       450
#  31   Fluffy Pancakes with Wheat Germ and Applesauce       31       174
#  83                            Cranberry Apple Bread       83       179
#  83                      Extra-Yummy Fluffy Pancakes       83       218
#  54              Neiman Marcus Chocolate Chip Cookie       54       325
#  67                        Artichoke Spinach Lasagna       67       396
#  ..                                              ...      ...       ...
#  71          Honey-Garlic Slow Cooker Chicken Thighs       71       325
#  13                       Slow Cooker Moscow Chicken       13       446
#  66                Chicken with 20 Cloves of Garlic        66       525
#  56                         Michelle's Roast Chicken       56       326
#  72                    Toasted Coconut Chicken Salad       72       205
#  51                                 Kung Pao Chicken       51       437
#  51  Roasted Garlic Teriyaki Fried Rice with Chicken       51       246
#  0                                Chicken and Olives        0       645
#  61                      Sandy's Chicken Saltimbocca       61       350
#  40                      Stupid Simple Roast Chicken       40       383
#  11                           Whole Chicken In a Pan       11       697
#  71                      Masala-Spiced Roast Chicken       71       309
#  64                              Happy Roast Chicken       64       638
#  0                  Grilled Chicken with Peach Sauce        0       406
#  20                         Mom's Chicken En Cocotte       20       644
#  73                    Slow Cooker Chicken and Salsa       73       534
#  7                            Baked Beer Can Chicken        7       564
#  76              Memphis-Style Chicken Mac 'n Cheese       76       665
#  58                             Sausage-Cheese Balls       58       220
#  49                          Chinese Roasted Chicken       49       591
#  24                        Smoked Beer Butt Chicken        24       697
#  51               Gina's Crab Stuffed Chicken Breast       51       797
#  69                    Roast Chicken by Kevin Sbraga       69       691
#  91                      Robust Garlic Baked Chicken       91       688
#  11           Roast Chicken with Croutons and Onions       11       349
#  81                           Crispy Roasted Chicken       81       495
#  14                 Slow Cooker Pulled Chicken Tacos       14       324
#  38                      Bacon Ranch Chicken Skewers       38       441
#  0          Pancetta Wrapped Stuffed Chicken Breasts        0       285
#  40                         Amaretto Roasted Chicken       40       408
#
#      cholesterol  recipeid
#  83         65.0         1
#  49         71.0         2
#  54         25.0         3
#  34          0.0         4
#  9          10.0         5
#  59         26.0         6
#  9          62.0         7
#  51        104.0         8
#  66          0.0         9
#  83          0.0        10
#  83         10.0        11
#  36        128.0        12
#  83         51.0        13
#  68        132.0        14
#  70         86.0        15
#  98         51.0        16
#  36         56.0        17
#  31         12.0        18
#  98         27.0        19
#  47         30.0        20
#  13         52.0        21
#  54         27.0        22
#  98         48.0        23
#  78        175.0        24
#  60        118.0        25
#  31         78.0        26
#  83         16.0        27
#  83         35.0        28
#  54         36.0        29
#  67         42.0        30
#  ..          ...       ...
#  71         71.0      4015
#  13         88.0      4016
#  66         97.0      4017
#  56         82.0      4018
#  72         38.0      4019
#  51         66.0      4020
#  51         51.0      4021
#  0         208.0      4022
#  61        116.0      4023
#  40        129.0      4024
#  11        226.0      4025
#  71         97.0      4026
#  64        198.0      4027
#  0          67.0      4028
#  20        113.0      4029
#  73        228.0      4030
#  7         145.0      4031
#  76        181.0      4032
#  58         37.0      4033
#  49        194.0      4034
#  24        145.0      4035
#  51        188.0      4036
#  69        211.0      4037
#  91        214.0      4038
#  11        128.0      4039
#  81        129.0      4040
#  14         64.0      4041
#  38        118.0      4042
#  0          92.0      4043
#  40        112.0      4044
#
#  [3941 rows x 5 columns],
#  'model': KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=100, n_init=10,
#      n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#      verbose=0),
#  'vectorizer': TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#          dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#          lowercase=True, max_df=0.8, max_features=200000, min_df=0.2,
#          ngram_range=(1, 3), norm=u'l2', preprocessor=None, smooth_idf=True,
#          stop_words='english', strip_accents=None, sublinear_tf=False,
#          token_pattern=u'(?u)\\b\\w\\w+\\b',
#          tokenizer=<function tokenize_and_stem at 0x7f691ad03c80>,
#          use_idf=True, vocabulary=None)}

# %%
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")
tips = sns.load_dataset("tips")
ax = sns.boxplot(x=a["cholesterol"])
